# %%
setwd("D:/Bioinfomation_Project/Create_R_Package")

# %%
options(warn = -1)
suppressMessages(library(tidyverse))
suppressMessages(library(CARD))
suppressMessages(library(data.table))
suppressMessages(library(Seurat))
suppressMessages(library(spacexr))
suppressMessages(library(Giotto))
suppressMessages(library(future))
suppressMessages(library(dplyr))
suppressMessages(library(SPOTlight))
suppressMessages(library(igraph))
suppressMessages(library(SeuratDisk))
suppressMessages(library(patchwork))
suppressMessages(library(Matrix))
suppressMessages(library(data.table))
suppressMessages(library(spdep))
suppressMessages(library(spatialreg))
suppressMessages(library(gridExtra))
suppressMessages(library(msigdbr))
suppressMessages(library(fields))
suppressMessages(library(Spatialsmooth))

# %%
scrna_path = 'Spatialsmooth/Example/sc_rna.h5seurat'
spatial_path = 'Spatialsmooth/Example/st_data.h5seurat'
celltype_final = 'celltype'
python_path = "D:/Application/anaconda3/envs/python_3.10"
output_path = 'output/test_output/'

# 运行所有方法
run_deconvolution_methods(scrna_path, spatial_path,celltype_final, python_path, output_path)
# Out:
# Running CARD ...
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding miscellaneous information for RNA
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding miscellaneous information for RNA
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
# ## QC on scRNASeq dataset! ...
# ## QC on spatially-resolved dataset! ...
# ## create reference matrix from scRNASeq...
# Loading required package: nnls
#
# Loading required package: TOAST
#
# Loading required package: EpiDISH
#
# Loading required package: limma
#
#
# Attaching package: 'limma'
#
#
# The following object is masked from 'package:BiocGenerics':
#
#     plotMA
#
#
# Loading required package: quadprog
#
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
#
# MuSiC v1.0.0 support SingleCellExperiment! See Tutorial: https://xuranw.github.io/MuSiC/articles/MuSiC.html
#
# MuSiC2 for multi-condition bulk RNA-seq data is also available!
# ## Select Informative Genes! ...
# ## Deconvolution Starts! ...
# ## Deconvolution Finish! ...
# CARD completed successfully.
# Running RCTD ...
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding miscellaneous information for RNA
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
# [1] "prepare data"
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding miscellaneous information for RNA
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Begin: process_cell_type_info
#
# process_cell_type_info: number of cells in reference: 1926
#
# process_cell_type_info: number of genes in reference: 19736
#                         Acinar_cells                       Cancer_clone_A
#                                   13                                  126
#                       Cancer_clone_B            Ductal_APOL1_high-hypoxic
#                                  170                                  215
# Ductal_CRISP3_high-centroacinar_like                  Ductal_MHC_Class_II
#                                  529                                  287
#          Ductal_terminal_ductal_like                      Endocrine_cells
#                                  350                                    3
#                    Endothelial_cells                          Fibroblasts
#                                   11                                    5
#                        Macrophages_A                        Macrophages_B
#                                   21                                   19
#                           Mast_cells                               mDCs_A
#                                   14                                   12
#                               mDCs_B                            Monocytes
#                                   33                                   18
#                                 pDCs                                 RBCs
#                                   13                                   15
#                   T_cells_&_NK_cells                           Tuft_cells
#                                   40                                   32
# End: process_cell_type_info
#
# create.RCTD: getting regression differentially expressed genes:
#
# get_de_genes: Acinar_cells found DE genes: 57
#
# get_de_genes: Cancer_clone_A found DE genes: 324
#
# get_de_genes: Cancer_clone_B found DE genes: 342
#
# get_de_genes: Ductal_APOL1_high-hypoxic found DE genes: 330
#
# get_de_genes: Ductal_CRISP3_high-centroacinar_like found DE genes: 225
#
# get_de_genes: Ductal_MHC_Class_II found DE genes: 259
#
# get_de_genes: Ductal_terminal_ductal_like found DE genes: 264
#
# get_de_genes: Endocrine_cells found DE genes: 769
#
# get_de_genes: Endothelial_cells found DE genes: 474
#
# get_de_genes: Fibroblasts found DE genes: 709
#
# get_de_genes: Macrophages_A found DE genes: 331
#
# get_de_genes: Macrophages_B found DE genes: 390
#
# get_de_genes: Mast_cells found DE genes: 335
#
# get_de_genes: mDCs_A found DE genes: 386
#
# get_de_genes: mDCs_B found DE genes: 282
#
# get_de_genes: Monocytes found DE genes: 478
#
# get_de_genes: pDCs found DE genes: 556
#
# get_de_genes: RBCs found DE genes: 18
#
# get_de_genes: T_cells_&_NK_cells found DE genes: 390
#
# get_de_genes: Tuft_cells found DE genes: 406
#
# get_de_genes: total DE genes: 4030
#
# create.RCTD: getting platform effect normalization differentially expressed genes:
#
# get_de_genes: Acinar_cells found DE genes: 75
#
# get_de_genes: Cancer_clone_A found DE genes: 814
#
# get_de_genes: Cancer_clone_B found DE genes: 793
#
# get_de_genes: Ductal_APOL1_high-hypoxic found DE genes: 686
#
# get_de_genes: Ductal_CRISP3_high-centroacinar_like found DE genes: 554
#
# get_de_genes: Ductal_MHC_Class_II found DE genes: 618
#
# get_de_genes: Ductal_terminal_ductal_like found DE genes: 617
#
# get_de_genes: Endocrine_cells found DE genes: 1330
#
# get_de_genes: Endothelial_cells found DE genes: 1123
#
# get_de_genes: Fibroblasts found DE genes: 1281
#
# get_de_genes: Macrophages_A found DE genes: 671
#
# get_de_genes: Macrophages_B found DE genes: 812
#
# get_de_genes: Mast_cells found DE genes: 732
#
# get_de_genes: mDCs_A found DE genes: 881
#
# get_de_genes: mDCs_B found DE genes: 563
#
# get_de_genes: Monocytes found DE genes: 899
#
# get_de_genes: pDCs found DE genes: 1231
#
# get_de_genes: RBCs found DE genes: 39
#
# get_de_genes: T_cells_&_NK_cells found DE genes: 962
#
# get_de_genes: Tuft_cells found DE genes: 970
#
# get_de_genes: total DE genes: 6351
#
# fitBulk: decomposing bulk
#
# chooseSigma: using initial Q_mat with sigma =  1
#
# Likelihood value: 687228.018597623
#
# Sigma value:  0.84
#
# Likelihood value: 682625.148132922
#
# Sigma value:  0.69
#
# Likelihood value: 680550.270825191
#
# Sigma value:  0.66
#
# Likelihood value: 680435.391127476
#
# Sigma value:  0.65
#
# Likelihood value: 680420.862886743
#
# Sigma value:  0.64
#
# Likelihood value: 680418.540217078
#
# Sigma value:  0.64
# RCTD completed successfully.
# Running SPOTlight ...
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding miscellaneous information for RNA
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Validating h5Seurat file
#
# Initializing RNA with data
#
# Adding counts for RNA
#
# Adding miscellaneous information for RNA
#
# Adding command information
#
# Adding cell-level metadata
#
# Adding miscellaneous information
#
# Adding tool-specific results
#
# Calculating cluster Acinar_cells
#
# Calculating cluster Ductal_terminal_ductal_like
#
# Calculating cluster Ductal_CRISP3_high-centroacinar_like
#
# Calculating cluster Cancer_clone_A
#
# Calculating cluster Ductal_MHC_Class_II
#
# Calculating cluster Cancer_clone_B
#
# Calculating cluster mDCs_A
#
# Calculating cluster Ductal_APOL1_high-hypoxic
#
# Calculating cluster Tuft_cells
#
# Calculating cluster mDCs_B
#
# Calculating cluster pDCs
#
# Calculating cluster Endocrine_cells
#
# Calculating cluster Endothelial_cells
#
# Calculating cluster Macrophages_A
#
# Calculating cluster Mast_cells
#
# Calculating cluster Macrophages_B
#
# Calculating cluster T_cells_&_NK_cells
#
# Calculating cluster Monocytes
#
# Calculating cluster RBCs
#
# Calculating cluster Fibroblasts
